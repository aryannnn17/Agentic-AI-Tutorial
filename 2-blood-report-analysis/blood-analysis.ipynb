# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
with open("blood_report.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:300])
# Out:
# Patient: Jignesh Bhagat, Age 40, Male
# Date: June 2, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        14.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        42%              (Normal: 41â€“53%)
# WBC:               6.8 x10^3/uL     (Normal: 4.5â€“11.0)
# Platelets:

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL 
based on the reference ranges provided in the report.

Format your response in json format:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range 

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# ```json
# {
#   "Complete Blood Count (CBC)": [
#     {
#       "Test Name": "Hemoglobin",
#       "Value": "14.1 g/dL",
#       "Status": "NORMAL",
#       "Reference": "13.5–17.5"
#     },
#     {
#       "Test Name": "Hematocrit",
#       "Value": "42%",
#       "Status": "NORMAL",
#       "Reference": "41–53%"
#     },
#     {
#       "Test Name": "WBC",
#       "Value": "6.8 x10^3/uL",
#       "Status": "NORMAL",
#       "Reference": "4.5–11.0"
#     },
#     {
#       "Test Name": "Platelets",
#       "Value": "220 x10^3/uL",
#       "Status": "NORMAL",
#       "Reference": "150–400"
#     }
#   ],
#   "Lipid Panel": [
#     {
#       "Test Name": "Total Cholesterol",
#       "Value": "238 mg/dL",
#       "Status": "HIGH",
#       "Reference": "<200"
#     },
#     {
#       "Test Name": "LDL Cholesterol",
#       "Value": "162 mg/dL",
#       "Status": "HIGH",
#       "Reference": "<100"
#     },
#     {
#       "Test Name": "HDL Cholesterol",
#       "Value": "36 mg/dL",
#       "Status": "LOW",
#       "Reference": ">40"
#     },
#     {
#       "Test Name": "Triglycerides",
#       "Value": "188 mg/dL",
#       "Status": "HIGH",
#       "Reference": "<150"
#     }
#   ],
#   "Metabolic Panel": [
#     {
#       "Test Name": "Glucose (Fasting)",
#       "Value": "92 mg/dL",
#       "Status": "NORMAL",
#       "Reference": "70–99"
#     },
#     {
#       "Test Name": "HbA1c",
#       "Value": "5.3%",
#       "Status": "NORMAL",
#       "Reference": "<5.7%"
#     },
#     {
#       "Test Name": "Creatinine",
#       "Value": "1.0 mg/dL",
#       "Status": "NORMAL",
#       "Reference": "0.7–1.3"
#     },
#     {
#       "Test Name": "eGFR",
#       "Value": "82 mL/min",
#       "Status": "NORMAL",
#       "Reference": ">60"
#     }
#   ],
#   "Liver Function": [
#     {
#       "Test Name": "ALT",
#       "Value": "28 U/L",
#       "Status": "NORMAL",
#       "Reference": "7–40"
#     },
#     {
#       "Test Name": "AST",
#       "Value": "25 U/L",
#       "Status": "NORMAL",
#       "Reference": "10–40"
#     },
#     {
#       "Test Name": "Bilirubin Total",
#       "Value": "0.8 mg/dL",
#       "Status": "NORMAL",
#       "Reference": "0.2–1.2"
#     }
#   ]
# }
# ```

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Gujarati Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Gujarati Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of. 
   Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)

print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# ### Health Summary
# Your blood work indicates a healthy blood count, normal kidney/liver function, and stable blood sugar levels. However, your lipid profile shows high levels of "bad" cholesterol (LDL) and triglycerides, alongside low levels of "good" cholesterol (HDL). This imbalance increases the risk of plaque buildup in your arteries, which can affect heart health over time. You can significantly improve these numbers by adjusting your intake of certain fats, refined carbohydrates, and increasing physical activity.
#
# ***
#
# ### Gujarati Indian Diet Plan
#
# **(1) Foods to avoid**
# *   **Deep-fried snacks (Farsan):** Reduce intake of Gathiya, Fafda, Bhajiya, Sev-Mamra, and Chakri, as these are high in trans fats and unhealthy oils.
# *   **Refined Carbohydrates:** Limit Maida-based items like Khaman/Dhokla (if made with excessive soda/sugar), white bread, naan, and biscuits.
# *   **Excessive Oil and Ghee:** Avoid cooking with excessive amounts of groundnut or cottonseed oil; avoid adding extra dollops of ghee to your Rotli or Dal.
# *   **Sugary Treats:** Limit traditional sweets (Mithai) like Shrikhand, Gulab Jamun, or sugary tea/coffee which contribute to high triglycerides.
#
# **(2) Foods to eat more of**
# *   **High Fiber Grains:** Replace white rice and wheat flour with Bajri (pearl millet), Jowar (sorghum), and Nachni (ragi) in your daily Rotli or Bhakri.
# *   **Legumes and Pulses:** Increase consumption of Moong dal, Chana dal, and sprouts (Matki/Chana), which are excellent sources of plant-based protein and fiber.
# *   **Heart-Healthy Fats:** Include a small handful of raw, unsalted walnuts and almonds daily; use cold-pressed mustard oil or olive oil in moderation for cooking.
# *   **Green Vegetables:** Increase the quantity of green leafy vegetables (Methi, Palak) and fibrous vegetables like Galka, Dudhi (bottle gourd), and Turiya in your daily vegetable preparations (Shaak).
